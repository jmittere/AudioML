# %%
import pandas as pd

df = pd.read_parquet(f'data/raw_parquets/train-00001-of-00015.parquet')
print(df.iloc[10])
# Out:
# audio                   {'bytes': b'ID3\x04\x00\x00\x00\x00\x04yTIT2\x...
# title                             Stakes Is High Instrumental     {U-N-I}
# url                     http://freemusicarchive.org/music/6th_Sense/It...
# artist                                                          6th Sense
# composer
# lyricist
# publisher
# genres                                                               [70]
# tags                                                                   []
# released                                              2009-04-30 15:03:53
# language                                                               en
# listens                                                              1979
# artist_url                   http://freemusicarchive.org/music/6th_Sense/
# artist_website                           http://notherground.blogspot.com
# album_title                                    It's A 6th Sense Beat Yo!!
# ...
